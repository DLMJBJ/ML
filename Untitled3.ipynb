# %%
import pandas as pd

DataURL = 'https://raw.githubusercontent.com/Datamanim/pandas/main/Jeju.csv'
df = pd.read_csv(DataURL, encoding='euc-kr')

# %%
df.head()
# Out:
#       id          일자   시도명  읍면동명         거주인구       근무인구        방문인구  \
# 0  22448  2018-01-01   제주시   도두동    32249.987   3418.266  102709.092
# 1  22449  2018-01-01   제주시   외도동   213500.997  10341.172  112692.789
# 2  22450  2018-01-01   제주시  이도2동  1212382.218  96920.834  541194.481
# 3  22451  2018-01-01   제주시  일도1동    33991.653   6034.253   72155.919
# 4  22452  2018-01-01  서귀포시   대천동   155036.925   9403.969  150882.409
#
#         총 유동인구   평균 속도  평균 소요 시간  평균 기온  일강수량  평균 풍속
# 0   138377.345  39.556    29.167    5.0   0.0    2.5
# 1   336534.958  32.900    30.900    5.0   0.0    2.5
# 2  1850497.533  29.538    35.692    2.9   0.0    2.4
# 3   112181.825  30.000    23.500    2.9   0.0    2.4
# 4   315323.303  41.583    14.375    5.1   0.0    2.3

# %%
import matplotlib.pyplot as plt

display(df.describe())

IRQ = df['평균 속도'].quantile(0.75) - df['평균 속도'].quantile(0.25)
print(IRQ)
IRQ = df['거주인구'].quantile(0.75) - df['거주인구'].quantile(0.25)
print(IRQ)
IRQ = df['근무인구'].quantile(0.75) - df['근무인구'].quantile(0.25)
print(IRQ)
IRQ = df['방문인구'].quantile(0.75) - df['방문인구'].quantile(0.25)
print(IRQ)
IRQ = df['총 유동인구'].quantile(0.75) - df['총 유동인구'].quantile(0.25)
print(IRQ)

print(df['평균 속도'].quantile(0.75))
print(df['평균 속도'].quantile(0.25))
print(IRQ)

df['거주인구'].count()
# Out:
#                  id          거주인구           근무인구           방문인구        총 유동인구  \
# count   9621.000000  9.621000e+03    9621.000000    9621.000000  9.621000e+03
# mean   27258.000000  3.174315e+05   35471.201510  195889.561802  5.487922e+05
# std     2777.487804  2.982079e+05   40381.214775  140706.090325  4.608802e+05
# min    22448.000000  9.305552e+03    1407.936000   11538.322000  2.225181e+04
# 25%    24853.000000  9.539939e+04   12074.498000   99632.153000  2.216910e+05
# 50%    27258.000000  2.221105e+05   21960.928000  152805.335000  3.866935e+05
# 75%    29663.000000  4.106671e+05   40192.032000  236325.109000  6.406918e+05
# max    32068.000000  1.364504e+06  263476.965000  723459.209000  2.066484e+06
#
#              평균 속도     평균 소요 시간        평균 기온         일강수량        평균 풍속
# count  9621.000000  9621.000000  9621.000000  9621.000000  9621.000000
# mean     41.109084    37.215873    13.550828     6.972426     2.753171
# ...

# %%
plt.boxplot(df['평균 속도'])
plt.show()

# %%
DataUrl = 'https://raw.githubusercontent.com/Datamanim/pandas/main/chipo.csv' 
df = pd.read_csv(DataUrl)
Ans = type(df)
Ans
# Out:
# pandas.core.frame.DataFrame

# %%
df[df['quantity'] == 3].head(10)
# Out:
#       order_id  quantity            item_name  \
# 409        178         3         Chicken Bowl
# 445        193         3                 Bowl
# 689        284         3    Canned Soft Drink
# 818        338         3        Bottled Water
# 850        350         3    Canned Soft Drink
# 917        379         3    Canned Soft Drink
# 1255       511         3        Steak Burrito
# 1514       616         3         Chicken Bowl
# 1559       633         3    Canned Soft Drink
# 2645      1051         3  Chips and Guacamole
#
#                                      choice_description item_price
# 409   [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...    $32.94
# 445   [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 689                                         [Diet Coke]     $3.75
# 818                                                 NaN     $3.27
# 850                                            [Sprite]     $3.75
# ...

# %%
df[df['quantity'] == 3].reset_index(drop=True).head(10)
# Out:
#    order_id  quantity            item_name  \
# 0       178         3         Chicken Bowl
# 1       193         3                 Bowl
# 2       284         3    Canned Soft Drink
# 3       338         3        Bottled Water
# 4       350         3    Canned Soft Drink
# 5       379         3    Canned Soft Drink
# 6       511         3        Steak Burrito
# 7       616         3         Chicken Bowl
# 8       633         3    Canned Soft Drink
# 9      1051         3  Chips and Guacamole
#
#                                   choice_description item_price
# 0  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...    $32.94
# 1  [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 2                                        [Diet Coke]     $3.75
# 3                                                NaN     $3.27
# 4                                           [Sprite]     $3.75
# 5                                         [Lemonade]     $3.75
# ...

# %%
df2 = df[['quantity', 'item_price']]
df2.head()
# Out:
#    quantity item_price
# 0         1     $2.39
# 1         1     $3.39
# 2         1     $3.39
# 3         1     $2.39
# 4         2    $16.98

# %%
df2['new_pirce'] = df2['item_price'].str.replace("$", "", regex = True)
df2['new_pirce'] = df2['new_pirce'].astype('float64')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   quantity    4622 non-null   int64
#  1   item_price  4622 non-null   object
#  2   new_pirce   4622 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 108.5+ KB
# C:\Users\JangBeomJun\AppData\Local\Temp\ipykernel_13700\1025312385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['new_pirce'] = df2['item_price'].str.replace("$", "", regex = True)
# C:\Users\JangBeomJun\AppData\Local\Temp\ipykernel_13700\1025312385.py:2: SettingWithCopyWarning:
# ...

# %%
df2[df2['new_pirce'] <= 5].head()

# df2[df2['new_pirce'] <= 5].size
# Out:
#    quantity item_price  new_pirce
# 0         1     $2.39        2.39
# 1         1     $3.39        3.39
# 2         1     $3.39        3.39
# 3         1     $2.39        2.39
# 6         1     $1.69        1.69

# %%
df3 = df[(df['item_name'] == 'Chicken Salad Bowl')]
df3.head()
# Out:
#      order_id  quantity           item_name  \
# 44         20         1  Chicken Salad Bowl
# 135        60         2  Chicken Salad Bowl
# 213        94         2  Chicken Salad Bowl
# 256       111         1  Chicken Salad Bowl
# 315       137         2  Chicken Salad Bowl
#
#                                     choice_description item_price
# 44   [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
# 135  [Tomatillo Green Chili Salsa, [Sour Cream, Che...    $22.50
# 213  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $22.50
# 256  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $8.75
# 315            [Fresh Tomato Salsa, Fajita Vegetables]    $17.50

# %%
df3['new_pirce'] = df3['item_price'].str.replace("$", "", regex = True)
df3['new_pirce'] = df3['new_pirce'].astype('float64')
# Out:
# C:\Users\JangBeomJun\AppData\Local\Temp\ipykernel_13700\2199963878.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['new_pirce'] = df3['item_price'].str.replace("$", "", regex = True)
# C:\Users\JangBeomJun\AppData\Local\Temp\ipykernel_13700\2199963878.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['new_pirce'] = df3['new_pirce'].astype('float64')

# %%
df3[df3['new_pirce'] <= 9]
# Out:
#       order_id  quantity           item_name  \
# 44          20         1  Chicken Salad Bowl
# 256        111         1  Chicken Salad Bowl
# 526        220         1  Chicken Salad Bowl
# 528        221         1  Chicken Salad Bowl
# 529        221         1  Chicken Salad Bowl
# 568        234         1  Chicken Salad Bowl
# 585        240         1  Chicken Salad Bowl
# 693        286         1  Chicken Salad Bowl
# 702        289         1  Chicken Salad Bowl
# 762        314         1  Chicken Salad Bowl
# 1109       458         1  Chicken Salad Bowl
# 1460       592         1  Chicken Salad Bowl
# 1471       598         1  Chicken Salad Bowl
# 1483       602         1  Chicken Salad Bowl
# 1547       628         1  Chicken Salad Bowl
# 1601       649         1  Chicken Salad Bowl
# 1621       654         1  Chicken Salad Bowl
# 1756       709         1  Chicken Salad Bowl
# 1977       798         1  Chicken Salad Bowl
# 2031       818         1  Chicken Salad Bowl
# ...

# %%
tmp = df3.sort_values('new_pirce').reset_index(drop=True)
tmp.head()
# Out:
#    order_id  quantity           item_name  \
# 0        20         1  Chicken Salad Bowl
# 1      1329         1  Chicken Salad Bowl
# 2      1327         1  Chicken Salad Bowl
# 3      1305         1  Chicken Salad Bowl
# 4      1305         1  Chicken Salad Bowl
#
#                                   choice_description item_price  new_pirce
# 0  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
# 1              [Fresh Tomato Salsa, [Rice, Lettuce]]     $8.75        8.75
# 2                               [Fresh Tomato Salsa]     $8.75        8.75
# 3  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75        8.75
# 4  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75

# %%
tmp = df.loc[df['item_name'].str.contains('Chips')]
tmp.head()
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 6          3         1                          Side of Chips
# 10         5         1                    Chips and Guacamole
# 14         7         1                    Chips and Guacamole
#
#    choice_description item_price
# 0                 NaN     $2.39
# 3                 NaN     $2.39
# 6                 NaN     $1.69
# 10                NaN     $4.45
# 14                NaN     $4.45

# %%
tmp = df.iloc[:,::2]
tmp.head()
# Out:
#    order_id                              item_name item_price
# 0         1           Chips and Fresh Tomato Salsa     $2.39
# 1         1                                   Izze     $3.39
# 2         1                       Nantucket Nectar     $3.39
# 3         1  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4         2                           Chicken Bowl    $16.98

# %%
tmp = df3.sort_values('new_pirce').reset_index(drop=True)
tmp.head()

# %%
tmp = df.loc[(df.item_name=='Steak Salad') | (df.item_name=='Bowl')].drop_duplicates('item_name',keep='first')
tmp.head()
# Out:
#      order_id  quantity    item_name  \
# 445       193         3         Bowl
# 664       276         1  Steak Salad
#
#                                     choice_description item_price
# 445  [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 664  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99

# %%
tmp = df.loc[(df.item_name=='Steak Salad') | (df.item_name=='Bowl')].drop_duplicates('item_name',keep='last')
tmp.head()
# Out:
#       order_id  quantity    item_name  \
# 673        279         1         Bowl
# 3502      1406         1  Steak Salad
#
#                                      choice_description item_price
# 673   [Adobo-Marinated and Grilled Steak, [Sour Crea...     $7.40
# 3502                        [[Lettuce, Fajita Veggies]]     $8.69

# %%
df.loc[df.item_name=='Izze','item_name'] = 'Fizzy Lizzy'
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                            Fizzy Lizzy
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
